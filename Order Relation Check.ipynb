# %% [markdown]
# # Find Frequent Order Customer List

# %%
from util_dao_mysql import VecsInfoDao
import pandas as pd
from mosql.util import raw
vecs_dao = VecsInfoDao()
freq_customer = vecs_dao.get_dao().select('oc_order', where={'order_status_id in':[40, 20, 28, 32]}, 
                                 columns=raw('customer_id, count(customer_id)'), 
                                 group_by=('customer_id', ), order_by=raw('count(customer_id) desc'))
df_freq_customer_meta = pd.DataFrame(freq_customer, columns=['customer_id', 'freq'])
df_freq_customer_meta.head()
# Out:
#    customer_id  freq
# 0           47    15
# 1          338    13
# 2         1737    11
# 3          798     8
# 4          242     7

# %%
customer_table = vecs_dao.get_dao().select('oc_customer', columns=['customer_id', 'lastname', 'firstname', 'email', 'address_id'], order_by='customer_id asc')
df_customer_table_meta = pd.DataFrame(customer_table, columns=['customer_id', 'lastname', 'firstname', 'email', 'address_id'])
df_customer_table_meta.head()
# Out:
#    customer_id lastname firstname                   email  address_id
# 0            4     Hung       Wei    b98608042@ntu.edu.tw           7
# 1            5        劉        雯瑄    violia.liu@gmail.com           8
# 2            6        李        衝衝  sxxxx9999@yahoo.com.tw           9
# 3            7      Lee       Ivy  ivyleeloveuk@gmail.com          11
# 4            8        胡        穎穎  chumiffy0403@gmail.com          12

# %%
address_table = vecs_dao.get_dao().select('oc_address', columns=['address_id', 'city', 'address_1'], order_by='address_id asc')
df_address_table = pd.DataFrame(address_table, columns=['address_id', 'city', 'address_1']).set_index('address_id')
df_customer_table = df_customer_table_meta.join(df_address_table, on='address_id').set_index('customer_id')
df_customer_table.head()
# Out:
#             lastname firstname                   email  address_id city  \
# customer_id
# 4               Hung       Wei    b98608042@ntu.edu.tw           7  NaN
# 5                  劉        雯瑄    violia.liu@gmail.com           8  NaN
# 6                  李        衝衝  sxxxx9999@yahoo.com.tw           9  NaN
# 7                Lee       Ivy  ivyleeloveuk@gmail.com          11  NaN
# 8                  胡        穎穎  chumiffy0403@gmail.com          12  NaN
#
#             address_1
# customer_id
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN

# %%
df_freq_customer = df_freq_customer_meta.join(df_customer_table, on='customer_id')
df_freq_customer.drop('address_id',1, inplace=True)
df_freq_customer.to_csv('freq_customer.csv', delimiter =';', encoding ='utf-8')
df_freq_customer[df_freq_customer.freq > 1]
# Out:
#      customer_id  freq           lastname firstname  \
# 0             47    15                  郭        純卉
# 1            338    13           Gardenia      Vecs
# 2           1737    11                  劉        依瑩
# 3            798     8                  陳        欣蔚
# 4            242     7                  楊        依珊
# 5            595     6                  郭        笛笛
# 6           2642     6                  蔡        如涵
# 7             59     6                  吳        書嫺
# 8           2218     6                  邱        凡芸
# 9           3381     6              Chang     Ching
# 10          1369     6                  余        思萱
# 11          1419     6                  邱        雅絨
# 12           515     6                  許        瑛蘭
# 13          3236     5                  陳        玉沼
# 14          1057     5                  陳        慧純
# 15          1040     5                  林        怡綾
# 16          2231     5              Cheng     Alisa
# 17          2835     5                  張        嵐喻
# 18          1141     5                  謝        容書
# 19          2997     5                  吳        采玲
# 20          1402     5                  張        婉貞
# 21          2078     5                  吳        淑芬
# 22          2710     5                  陳        昱潔
# 23          2599     5                  洪        詳臻
# 24          1632     4                  陳        書芸
# 25          1814     4                  陳        雅莉
# 26          3000     4                  葉        沛緹
# 27            71     4                  林        芸安
# 28          1963     4                  廖        婉君
# 29          3240     4                  魏        薇薇
# ..           ...   ...                ...       ...
# 293         2288     2               Chou     Ariel
# 294         3317     2                  溫        歡歡
# 295         3352     2                  塗        偉哲
# 296         1738     2                  黃        金菊
# 297         3595     2                  欒        依萍
# 298          944     2                  林        玉環
# 299         1004     2                  陳        綺瑩
# 300         1643     2                  蕭        淳憶
# 301         3111     2                  劉        汝育
# 302         3335     2              Alice      Ieng
# 303          843     2                  林        楚菁
# 304         3548     2                  張        鳳屏
# 305          960     2                  張        雅萍
# 306         1085     2                  陳        俞君
# 307         2996     2                  陳        雅雯
# 308         3593     2                  王        鵬雲
# 309           26     2                  黃        郁庭
# 310          901     2                  美        樂蒂
# 311         1166     2                  賴        孟利
# 312         1581     2                  陳        姵如
# 313         1629     2                  郭        娟娟
# 314         1718     2                  黃        詩詩
# 315         2707     2  Ka Wing , connie       Pau
# 316         3319     2                  張        馨尹
# 317         1422     2                  林        詩宸
# 318         1483     2                Gan    Jaymee
# 319          795     2                  林        佑多
# 320         3116     2                  林        思維
# 321         3169     2                  崔        玉佩
# 322         3555     2                  姚        凱瑜
#
#                                    email        city  \
# 0                littlerunandy@gmail.com         南港區
# 1                 vecsgardenia@gmail.com         NaN
# 2                 a19958197@yahoo.com.tw         NaN
# 3             sherry3975189@Yahoo.com.tw         三民區
# 4                  bear76703@hotmail.com      彰化縣員林鎮
# 5                   shs7798@yahoo.com.tw         鳳山區
# 6                  teddy514@yahoo.com.tw         高雄市
# 7               angel000412002@gmail.com         壯圍鄉
# 8                   s299209@yahoo.com.tw         屏東市
# 9                  shuling0906@gmail.com         西屯區
# 10               candyyu0407@hotmail.com         南港區
# 11                   th5886@yahoo.com.tw         安南區
# 12           wow1238wow1238@yahoo.com.tw         萬丹鄉
# 13                a79326148@yahoo.com.tw         埤頭鄉
# 14                 iris79704@hotmail.com         NaN
# 15                   lynne0985@gmail.com      基隆市七堵區
# 16                  rockwoon@hotmail.com         新城鄉
# 17               lanyun10186@hotmail.com         竹崎鄉
# 18                   bjvuph@yahoo.com.tw         莿桐鄉
# 19               wonbin0924@yahoo.com.tw         彰化市
# 20                  jenny@enerage.com.tw         五結鄉
# 21               lovsea2001@yahoo.com.tw         萬丹鄉
# 22                   j10013147@gmail.com         新北市
# 23                 j_860713@yahoo.com.tw         台北市
# 24                 c-w.1985@yahoo.com.tw         淡水區
# 25                   majselt@hotmail.com          東區
# 26                peitiyeh1013@gmail.com         台北市
# 27                  amy.lin.31@gmail.com         新北市
# 28                donut_liao@hotmail.com         新店區
# 29            kelly19930316@yahoo.com.tw         台中市
# ..                                   ...         ...
# 293                ariel0903@hotmail.com         中山區
# 294                qqpp530@pchome.com.tw         竹東鎮
# 295          n1242649002004@yahoo.com.tw         彰化縣
# 296  sunny_huang@email.eternal-group.com         小港區
# 297            money123momo@yahoo.com.tw         NaN
# 298                ker_01_01@hotmail.com         三重區
# 299                momo6161@yahoo.com.tw         台南市
# 300              minnie_1110@hotmail.com         南屯區
# 301                 lulu130.tw@gmail.com         新店區
# 302              ieng-orange@hotmail.com         安南區
# 303                pinkjing917@gmail.com         信義區
# 304                  P73331@yahoo.com.tw         NaN
# 305                 h236182@yahoo.com.tw         大園鄉
# 306                   myibkh@hotmail.com       新竹市東區
# 307                   ewting@hotmail.com         台中市
# 308               koopp1014@yahoo.com.tw         NaN
# 309                 maru800912@gmail.com         土城區
# 310              ayumimay53@yahoo.com.tw         NaN
# 311                    m121583@gmail.com          東區
# 312                    m912026@gmail.com         新營區
# 313               norika2427@hotmail.com          北區
# 314                    tingjts@gmail.com         斗六市
# 315               konnie_pau@hotmail.com  hong kong
# 316              abby810802@yahoo.com.tw         新莊區
# 317            lin_11062002@yahoo.com.tw         新莊區
# 318               jaymee.gan10@gmail.com   Singapore
# 319                 gim0730@yahoo.com.tw         花蓮縣
# 320            vivi12148150@yahoo.com.tw         北　區
# 321                  may197517@gmail.com         台北市
# 322                101601152@nccu.edu.tw         NaN
#
#                                              address_1
# 0                                           南港路三段48號九樓
# 1                                                  NaN
# 2                                                  NaN
# 3                                     高雄市三民區大昌二路301號9樓
# 4                                      彰化縣員林鎮員集路一段576號
# 5                                              鳳甲路279號
# 6                                         高雄市三民區更新街55號
# 7                                       美城村美功路二段51巷18號
# 8                                        屏東市迪化街75號3樓之1
# 9                                        青海路二段175號二樓之三
# 10                                          東明街55號8F之一
# 11                               台南市安南區安中路四段四巷48弄22之3號
# 12                                      屏東縣萬丹鄉萬新路1238號
# 13                                           彰水路二段837號
# 14                                                 NaN
# 15                                    崇孝街42巷48弄14-3號4樓
# 16                                          嘉里路163之48號
# 17                                    和平村坑仔坪163號(竹崎地政)
# 18                                     雲林縣莿桐鄉五華村湖內路82號
# 19                                   500彰化市彰南路二段55巷36號
# 20                                        宜蘭縣五結鄉利工三路5號
# 21                                          社皮村吉豐路226號
# 22                                      新北市五股區工商路97號4樓
# 23                                 台北市信義區福德街232巷六弄4號3樓
# 24                                        民生路145巷54號2F
# 25                                        食品路366巷15弄2號
# 26                               台北市內湖區民權東路六段161-11號7樓
# 27                               22042 新北市板橋區萬板路155號9樓
# 28                                    新北市新店區自立街103號15樓
# 29                                       台中市西區福龍街62號2樓
# ..                                                 ...
# 293                                          復興路42巷22號
# 294                                         二重里學府路102號
# 295                                     北斗鎮中寮里中寮三路六十八號
# 296                                              松安街9號
# 297                                                NaN
# 298                                        忠孝路2段34號10樓
# 299                                    開元路212巷52號（森2A)
# 300                                      文心路一段191號2樓之3
# 301                                          中央ㄧ街47號9樓
# 302                                  台南市安南區安中路四段238號全家
# 303                               台北市信義區東興路71號9樓(法務部門)
# 304                                                NaN
# 305                                      桃園縣大園鄉中正東路86號
# 306                                  新竹市光復路二段295號18樓之8
# 307                                    台中市后里區泉州路21-13號
# 308                                                NaN
# 309                                                裕生路
# 310                                                NaN
# 311                                      新竹市建功一路47巷19號
# 312                                          金華路一段380號
# 313                               台南市北區海安路三段338巷56-11號
# 314                                    虎溪里西平路600巷45-3號
# 315                             香港九龍觀塘觀塘道378號創紀之城2期12樓
# 316                                 新北市新莊區中正路829巷15號3樓
# 317                                       後港一路179號7樓之1
# 318  Blk 283, Tampines St-22, #06-111, Singapore 52...
# 319                                    吉安鄉北昌五街52號5樓之 9
# 320                                    武陵路175巷15號21樓之1
# 321                                    信義區信義路4段456號13樓
# 322                                                NaN
#
# [323 rows x 7 columns]
